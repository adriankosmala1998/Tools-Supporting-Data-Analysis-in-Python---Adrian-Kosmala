# %% [markdown]
# ### Załadowanie modułów, zapisanie ścieżek, nazw plików i parametrów

# %%
from npd_final_project.create_output.functions import *
from npd_final_project.import_data.functions import *
from npd_final_project.calculate_statistics.functions import *
import pandas as pd

#ścieżki
input_path = r'/home/adrian/npd/Projekt zaliczeniowy/'
output_path = r'/home/adrian/npd/Projekt zaliczeniowy/Analysis/'

#nazwy plików
name_gminy_2020 = '20210215_Gminy_2_za_2020.xlsx'
name_woj_2020 = '20210211_Województwa_za_2020.xlsx'
name_miasta_npp_2020 = '20210215_Miasta_NPP_2_za_2020.xlsx'
name_powiaty_2020 = '20210211_Powiaty_za_2020.xlsx'
name_metropolia_2020 ='20210211_Metropolia_2020.xlsx'

name_gminy_2019 = '20200214_Gminy_za_2019.xlsx'
name_woj_2019 = '20200214_Wojewodztwa_za_2019.xlsx'
name_miasta_npp_2019 = '20200214_Miasta_NPP_za_2019.xlsx'
name_powiaty_2019 = '20200214_Powiaty_za_2019.xlsx'
name_metropolia_2019 ='20200214_Gornoslasko_Zaglebiowska_Metropolia.xlsx'

name_population = 'tabela11.xls'

output_name_1 = 'Analysis_output_1.xlsx'
output_name_2 = 'Analysis_output_2.xlsx'

#parametry
tax_perc_2020 = 0.17
tax_perc_2019 = 0.18
working_people_share_2020 = 0.7
working_people_share_2019 = 0.7

# %% [markdown]
# # Prezentacja krok po kroku działania biblioteki

# %% [markdown]
# ### Zaimportowanie danych o populacji i należnym dochodzie z PIT dla każdej JST

# %%
population = import_data_population(input_path, name_population)
    
tax_2019 = import_data_tax_all(input_path, name_gminy_2019, name_woj_2019,
                               name_miasta_npp_2019, name_powiaty_2019,
                               name_metropolia_2019
                              )

tax_2020 = import_data_tax_all(input_path, name_gminy_2020, name_woj_2020,
                               name_miasta_npp_2020, name_powiaty_2020,
                               name_metropolia_2020
                              )
    
tax_2019, tax_2020 = update_teritorial_codes(tax_2019, tax_2020)

tax_2020
# Out:
#      Identyfikator terytorialny            Nazwa JST   Województwo  \
# 0                       0201011          BOLESŁAWIEC  dolnośląskie
# 1                       0201022          BOLESŁAWIEC  dolnośląskie
# 2                       0201032             GROMADKA  dolnośląskie
# 3                       0201043         NOWOGRODZIEC  dolnośląskie
# 4                       0201052           OSIECZNICA  dolnośląskie
# ...                         ...                  ...           ...
# 2803                    2400000              śląskie             -
# 2804                    2600000       świętokrzyskie             -
# 2805                    2800000  warmińsko-mazurskie             -
# 2806                    3000000        wielkopolskie             -
# 2807                    3200000   zachodniopomorskie             -
#
#              Powiat  Dochód przynależny JST Kategoria JST
# 0     bolesławiecki                40456699         Gmina
# 1     bolesławiecki                13789712         Gmina
# 2     bolesławiecki                 3573540         Gmina
# 3     bolesławiecki                 9553744         Gmina
# 4     bolesławiecki                 5844560         Gmina
# ...             ...                     ...           ...
# 2803              -               218863771   Województwo
# 2804              -                40133238   Województwo
# 2805              -                47344145   Województwo
# 2806              -               166394837   Województwo
# 2807              -                67677173   Województwo
#
# [2808 rows x 6 columns]

# %% [markdown]
# ### Obliczenie całkowitego podatku zapłaconego przez mieszkańców w JST

# %%
df_total_tax_2019 = calculate_total_people_tax(tax_2019)
df_total_tax_2020 = calculate_total_people_tax(tax_2020)

df_total_tax_2020
# Out:
#      Identyfikator terytorialny            Nazwa JST   Województwo  \
# 0                       0201011          BOLESŁAWIEC  dolnośląskie
# 1                       0201022          BOLESŁAWIEC  dolnośląskie
# 2                       0201032             GROMADKA  dolnośląskie
# 3                       0201043         NOWOGRODZIEC  dolnośląskie
# 4                       0201052           OSIECZNICA  dolnośląskie
# ...                         ...                  ...           ...
# 2803                    2400000              śląskie             -
# 2804                    2600000       świętokrzyskie             -
# 2805                    2800000  warmińsko-mazurskie             -
# 2806                    3000000        wielkopolskie             -
# 2807                    3200000   zachodniopomorskie             -
#
#              Powiat  Dochód przynależny JST Kategoria JST  \
# 0     bolesławiecki                40456699         Gmina
# 1     bolesławiecki                13789712         Gmina
# 2     bolesławiecki                 3573540         Gmina
# 3     bolesławiecki                 9553744         Gmina
# 4     bolesławiecki                 5844560         Gmina
# ...             ...                     ...           ...
# 2803              -               218863771   Województwo
# 2804              -                40133238   Województwo
# 2805              -                47344145   Województwo
# 2806              -               166394837   Województwo
# 2807              -                67677173   Województwo
#
#       Podatek całkowity ludności
# 0                   1.028386e+08
# 1                   3.505265e+07
# 2                   9.083732e+06
# 3                   2.428506e+07
# 4                   1.485653e+07
# ...                          ...
# 2803                1.367899e+10
# 2804                2.508327e+09
# 2805                2.959009e+09
# 2806                1.039968e+10
# 2807                4.229823e+09
#
# [2808 rows x 7 columns]

# %% [markdown]
# ### Przyłączenie danych o populacji

# %%
df_tax_population_2019 = join_population(df_total_tax_2019, population)
df_tax_population_2020 = join_population(df_total_tax_2020, population)

df_tax_population_2019 = calculate_metropolia_population(df_tax_population_2019)
df_tax_population_2020 = calculate_metropolia_population(df_tax_population_2020)

df_tax_population_2020
# Out:
#      Identyfikator terytorialny            Nazwa JST   Województwo  \
# 0                       0201011          BOLESŁAWIEC  dolnośląskie
# 1                       0201022          BOLESŁAWIEC  dolnośląskie
# 2                       0201032             GROMADKA  dolnośląskie
# 3                       0201043         NOWOGRODZIEC  dolnośląskie
# 4                       0201052           OSIECZNICA  dolnośląskie
# ...                         ...                  ...           ...
# 2803                    2400000              śląskie             -
# 2804                    2600000       świętokrzyskie             -
# 2805                    2800000  warmińsko-mazurskie             -
# 2806                    3000000        wielkopolskie             -
# 2807                    3200000   zachodniopomorskie             -
#
#              Powiat  Dochód przynależny JST Kategoria JST  \
# 0     bolesławiecki                40456699         Gmina
# 1     bolesławiecki                13789712         Gmina
# 2     bolesławiecki                 3573540         Gmina
# 3     bolesławiecki                 9553744         Gmina
# 4     bolesławiecki                 5844560         Gmina
# ...             ...                     ...           ...
# 2803              -               218863771   Województwo
# 2804              -                40133238   Województwo
# 2805              -                47344145   Województwo
# 2806              -               166394837   Województwo
# 2807              -                67677173   Województwo
#
#       Podatek całkowity ludności  Populacja
# 0                   1.028386e+08    38486.0
# 1                   3.505265e+07    14863.0
# 2                   9.083732e+06     5317.0
# 3                   2.428506e+07    15229.0
# 4                   1.485653e+07     7288.0
# ...                          ...        ...
# 2803                1.367899e+10  4492330.0
# 2804                2.508327e+09  1224626.0
# 2805                2.959009e+09  1416495.0
# 2806                1.039968e+10  3496450.0
# 2807                4.229823e+09  1688047.0
#
# [2808 rows x 8 columns]

# %% [markdown]
# ### Obliczenie średniego opodatkowanego dochodu na pracującego mieszkańca, połączenie danych z lat 2019 i 2020

# %%
df_avg_taxed_income_2019 = calculate_average_taxed_income(input_data = df_tax_population_2019,
                                                          tax = tax_perc_2019,
                                                          working_people_share = working_people_share_2019
                                                         )

df_avg_taxed_income_2020 = calculate_average_taxed_income(input_data = df_tax_population_2020,
                                                          tax = tax_perc_2020, 
                                                          working_people_share = working_people_share_2020
                                                         )


df_avg_income = df_avg_taxed_income_2019.merge(right =
                                                df_avg_taxed_income_2020[[  'Identyfikator terytorialny',
                                                                            'Dochód przynależny JST',
                                                                            'Podatek całkowity ludności',
                                                                            'Średni zapłacony podatek PIT', 
                                                                            'Średni dochód opodatkowany ludności'
                                                                        ]], 
                                                how = 'outer', 
                                                on = ['Identyfikator terytorialny'],
                                                suffixes = (' 2019', ' 2020')
                                              )

df_avg_income
# Out:
#      Identyfikator terytorialny Kategoria JST            Nazwa JST  \
# 0                       0201011         Gmina          BOLESŁAWIEC
# 1                       0201022         Gmina          BOLESŁAWIEC
# 2                       0201032         Gmina             GROMADKA
# 3                       0201043         Gmina         NOWOGRODZIEC
# 4                       0201052         Gmina           OSIECZNICA
# ...                         ...           ...                  ...
# 2803                    2400000   Województwo              śląskie
# 2804                    2600000   Województwo       świętokrzyskie
# 2805                    2800000   Województwo  warmińsko-mazurskie
# 2806                    3000000   Województwo        wielkopolskie
# 2807                    3200000   Województwo   zachodniopomorskie
#
#        Województwo         Powiat  Populacja  Dochód przynależny JST 2019  \
# 0     dolnośląskie  bolesławiecki    38486.0                     42642404
# 1     dolnośląskie  bolesławiecki    14863.0                     14042861
# 2     dolnośląskie  bolesławiecki     5317.0                      3550411
# 3     dolnośląskie  bolesławiecki    15229.0                      9498051
# 4     dolnośląskie  bolesławiecki     7288.0                      6055695
# ...            ...            ...        ...                          ...
# 2803             -              -  4492330.0                    224802573
# 2804             -              -  1224626.0                     41007726
# 2805             -              -  1416495.0                     49267070
# 2806             -              -  3496450.0                    168838005
# 2807             -              -  1688047.0                     69278810
#
#       Podatek całkowity ludności 2019  Średni zapłacony podatek PIT 2019  \
# 0                        1.083945e+08                        4023.523195
# 1                        3.569614e+07                        3430.968444
# 2                        9.024939e+06                        2424.820386
# 3                        2.414350e+07                        2264.804477
# 4                        1.539323e+07                        3017.332940
# ...                               ...                                ...
# 2803                     1.405016e+10                        4467.983942
# 2804                     2.562983e+09                        2989.814121
# 2805                     3.079192e+09                        3105.443744
# 2806                     1.055238e+10                        4311.465022
# 2807                     4.329926e+09                        3664.357708
#
#       Średni dochód opodatkowany ludności 2019  Dochód przynależny JST 2020  \
# 0                                 22352.906638                     40456699
# 1                                 19060.935801                     13789712
# 2                                 13471.224365                      3573540
# 3                                 12582.247097                      9553744
# 4                                 16762.960775                      5844560
# ...                                        ...                          ...
# 2803                              24822.133013                    218863771
# 2804                              16610.078447                     40133238
# 2805                              17252.465243                     47344145
# 2806                              23952.583454                    166394837
# 2807                              20357.542822                     67677173
#
#       Podatek całkowity ludności 2020  Średni zapłacony podatek PIT 2020  \
# 0                        1.028386e+08                        3817.291042
# 1                        3.505265e+07                        3369.118780
# 2                        9.083732e+06                        2440.616774
# 3                        2.428506e+07                        2278.084439
# 4                        1.485653e+07                        2912.132035
# ...                               ...                                ...
# 2803                     1.367899e+10                        4349.949386
# 2804                     2.508327e+09                        2926.056462
# 2805                     2.959009e+09                        2984.236304
# 2806                     1.039968e+10                        4249.076027
# 2807                     4.229823e+09                        3579.642470
#
#       Średni dochód opodatkowany ludności 2020
# 0                                 22454.653190
# 1                                 19818.345767
# 2                                 14356.569258
# 3                                 13400.496702
# 4                                 17130.188443
# ...                                        ...
# 2803                              25587.937564
# 2804                              17212.096838
# 2805                              17554.331201
# 2806                              24994.564865
# 2807                              21056.720410
#
# [2808 rows x 14 columns]

# %% [markdown]
# ### Policzenie statystyk dla województwa na poziomie powiatu

# %%
df_stats_woj_by_powiat_2019 = calculate_partial_statistics(df_avg_taxed_income_2019,
                                                           level = 'Województwo', 
                                                           by = 'Powiat'
                                                          )

df_stats_woj_by_powiat_2020 = calculate_partial_statistics(df_avg_taxed_income_2020,
                                                           level = 'Województwo',
                                                           by = 'Powiat'
                                                          )

df_stats_woj_by_powiat = df_stats_woj_by_powiat_2019.merge(right = df_stats_woj_by_powiat_2020,
                                                           how = 'outer',
                                                           on = 'Województwo',
                                                            suffixes = (' 2019', ' 2020')
                                                          )

df_stats_woj_by_powiat
# Out:
# /home/adrian/npd/Projekt zaliczeniowy/npd_final_project/calculate_statistics/functions.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['proxy_var'] = temp[variable] * temp[weight]
#                      Średni dochód opodatkowany ludności 2019  \
# Województwo
# dolnośląskie                                     25140.961100
# kujawsko-pomorskie                               19275.779910
# lubelskie                                        15916.154194
# lubuskie                                         19855.935393
# łódzkie                                          22260.950815
# małopolskie                                      22714.987302
# mazowieckie                                      35661.121535
# opolskie                                         18876.379131
# podkarpackie                                     15702.020082
# podlaskie                                        17560.237279
# pomorskie                                        23243.703274
# śląskie                                          24822.133013
# świętokrzyskie                                   16610.078447
# warmińsko-mazurskie                              17252.465243
# wielkopolskie                                    23952.583454
# zachodniopomorskie                               20357.542822
#
#                      Wariancja dochodu (Powiat) 2019  \
# Województwo
# dolnośląskie                            3.290175e+07
# kujawsko-pomorskie                      1.792530e+07
# lubelskie                               1.595119e+07
# lubuskie                                1.758616e+07
# łódzkie                                 1.937173e+07
# małopolskie                             4.208876e+07
# mazowieckie                             1.208766e+08
# opolskie                                1.666198e+07
# podkarpackie                            1.255931e+07
# podlaskie                               1.565987e+07
# pomorskie                               6.969818e+07
# śląskie                                 1.369917e+07
# świętokrzyskie                          1.372094e+07
# warmińsko-mazurskie                     1.328252e+07
# wielkopolskie                           2.759522e+07
# zachodniopomorskie                      2.331375e+07
#
#                      Średnia ważona dochodu (Powiat) 2019  \
# Województwo
# dolnośląskie                                 24873.181509
# kujawsko-pomorskie                           19054.546682
# lubelskie                                    15766.432384
# lubuskie                                     20097.933238
# łódzkie                                      22024.525335
# małopolskie                                  22463.834645
# mazowieckie                                  35122.726818
# opolskie                                     18775.394215
# podkarpackie                                 15607.547295
# podlaskie                                    17344.844537
# pomorskie                                    22945.921789
# śląskie                                      24447.210551
# świętokrzyskie                               16504.912699
# warmińsko-mazurskie                          17118.443560
# wielkopolskie                                23760.632238
# zachodniopomorskie                           20144.229759
#
#                      Średni dochód opodatkowany ludności 2020  \
# Województwo
# dolnośląskie                                     26119.015852
# kujawsko-pomorskie                               19852.187318
# lubelskie                                        16350.498915
# lubuskie                                         20283.504507
# łódzkie                                          23035.310744
# małopolskie                                      23834.593316
# mazowieckie                                      36810.718598
# opolskie                                         19455.573684
# podkarpackie                                     16262.731129
# podlaskie                                        18245.536611
# pomorskie                                        24914.725974
# śląskie                                          25587.937564
# świętokrzyskie                                   17212.096838
# warmińsko-mazurskie                              17554.331201
# wielkopolskie                                    24994.564865
# zachodniopomorskie                               21056.720410
#
#                      Wariancja dochodu (Powiat) 2020  \
# Województwo
# dolnośląskie                            3.630431e+07
# kujawsko-pomorskie                      1.832947e+07
# lubelskie                               1.602204e+07
# lubuskie                                1.326635e+07
# łódzkie                                 2.041047e+07
# małopolskie                             4.502914e+07
# mazowieckie                             1.306729e+08
# opolskie                                1.719883e+07
# podkarpackie                            1.258591e+07
# podlaskie                               1.720535e+07
# pomorskie                               7.795939e+07
# śląskie                                 1.413142e+07
# świętokrzyskie                          1.402756e+07
# warmińsko-mazurskie                     1.338696e+07
# wielkopolskie                           2.987380e+07
# zachodniopomorskie                      2.582737e+07
#
#                      Średnia ważona dochodu (Powiat) 2020
# Województwo
# dolnośląskie                                 25857.896783
# kujawsko-pomorskie                           19641.696495
# lubelskie                                    16208.343113
# lubuskie                                     20118.250286
# łódzkie                                      22808.265188
# małopolskie                                  23588.452192
# mazowieckie                                  36292.620585
# opolskie                                     19358.165080
# podkarpackie                                 16173.015687
# podlaskie                                    18036.305279
# pomorskie                                    24628.797044
# śląskie                                      25228.208869
# świętokrzyskie                               17110.945994
# warmińsko-mazurskie                          17427.995202
# wielkopolskie                                24809.217373
# zachodniopomorskie                           20850.728305

# %% [markdown]
# ### Policzenie statystyk dla województwa na poziomie gminy

# %%
df_stats_woj_by_gmina_2019 = calculate_partial_statistics(df_avg_taxed_income_2019,
                                                          level = 'Województwo',
                                                          by = 'Gmina'
                                                         )

df_stats_woj_by_gmina_2020 = calculate_partial_statistics(df_avg_taxed_income_2020,
                                                          level = 'Województwo',
                                                          by = 'Gmina'
                                                         )

df_stats_woj_by_gmina = df_stats_woj_by_gmina_2019.merge(right = df_stats_woj_by_gmina_2020,
                                                         how = 'outer',
                                                         on = 'Województwo',
                                                         suffixes = (' 2019', ' 2020')
                                                        )

df_stats_woj_by_gmina
# Out:
# /home/adrian/npd/Projekt zaliczeniowy/npd_final_project/calculate_statistics/functions.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['proxy_var'] = temp[variable] * temp[weight]
#                      Średni dochód opodatkowany ludności 2019  \
# Województwo
# dolnośląskie                                     25140.961100
# kujawsko-pomorskie                               19275.779910
# lubelskie                                        15916.154194
# lubuskie                                         19855.935393
# łódzkie                                          22260.950815
# małopolskie                                      22714.987302
# mazowieckie                                      35661.121535
# opolskie                                         18876.379131
# podkarpackie                                     15702.020082
# podlaskie                                        17560.237279
# pomorskie                                        23243.703274
# śląskie                                          24822.133013
# świętokrzyskie                                   16610.078447
# warmińsko-mazurskie                              17252.465243
# wielkopolskie                                    23952.583454
# zachodniopomorskie                               20357.542822
#
#                      Wariancja dochodu (Gmina) 2019  \
# Województwo
# dolnośląskie                           4.166425e+07
# kujawsko-pomorskie                     3.434760e+07
# lubelskie                              1.888801e+07
# lubuskie                               2.062958e+07
# łódzkie                                3.741059e+07
# małopolskie                            4.541831e+07
# mazowieckie                            1.330693e+08
# opolskie                               1.636303e+07
# podkarpackie                           1.600592e+07
# podlaskie                              2.838278e+07
# pomorskie                              3.648287e+07
# śląskie                                2.889663e+07
# świętokrzyskie                         1.617557e+07
# warmińsko-mazurskie                    2.505963e+07
# wielkopolskie                          5.891613e+07
# zachodniopomorskie                     3.110007e+07
#
#                      Średnia ważona dochodu (Gmina) 2019  \
# Województwo
# dolnośląskie                                24405.506382
# kujawsko-pomorskie                          18716.050207
# lubelskie                                   15445.395132
# lubuskie                                    19680.100386
# łódzkie                                     21609.568904
# małopolskie                                 22052.900275
# mazowieckie                                 34659.231167
# opolskie                                    18298.110517
# podkarpackie                                15223.724459
# podlaskie                                   17053.931958
# pomorskie                                   22576.831811
# śląskie                                     24124.806157
# świętokrzyskie                              16105.483650
# warmińsko-mazurskie                         16734.815641
# wielkopolskie                               23235.433036
# zachodniopomorskie                          19761.103519
#
#                      Średni dochód opodatkowany ludności 2020  \
# Województwo
# dolnośląskie                                     26119.015852
# kujawsko-pomorskie                               19852.187318
# lubelskie                                        16350.498915
# lubuskie                                         20283.504507
# łódzkie                                          23035.310744
# małopolskie                                      23834.593316
# mazowieckie                                      36810.718598
# opolskie                                         19455.573684
# podkarpackie                                     16262.731129
# podlaskie                                        18245.536611
# pomorskie                                        24914.725974
# śląskie                                          25587.937564
# świętokrzyskie                                   17212.096838
# warmińsko-mazurskie                              17554.331201
# wielkopolskie                                    24994.564865
# zachodniopomorskie                               21056.720410
#
#                      Wariancja dochodu (Gmina) 2020  \
# Województwo
# dolnośląskie                           4.677023e+07
# kujawsko-pomorskie                     3.668849e+07
# lubelskie                              2.023944e+07
# lubuskie                               2.080356e+07
# łódzkie                                4.058994e+07
# małopolskie                            4.897801e+07
# mazowieckie                            1.408135e+08
# opolskie                               1.523456e+07
# podkarpackie                           1.700901e+07
# podlaskie                              3.113143e+07
# pomorskie                              1.059365e+08
# śląskie                                3.185005e+07
# świętokrzyskie                         1.776284e+07
# warmińsko-mazurskie                    2.654673e+07
# wielkopolskie                          6.792004e+07
# zachodniopomorskie                     3.829936e+07
#
#                      Średnia ważona dochodu (Gmina) 2020
# Województwo
# dolnośląskie                                25403.596879
# kujawsko-pomorskie                          19311.553967
# lubelskie                                   15897.095062
# lubuskie                                    19718.159491
# łódzkie                                     22403.510443
# małopolskie                                 23183.794399
# mazowieckie                                 35841.551368
# opolskie                                    18897.373720
# podkarpackie                                15798.296684
# podlaskie                                   17752.767869
# pomorskie                                   24241.895356
# śląskie                                     24914.141113
# świętokrzyskie                              16722.166562
# warmińsko-mazurskie                         17060.696676
# wielkopolskie                               24293.131983
# zachodniopomorskie                          20478.783983

# %% [markdown]
# ### Policzenie statystyk dla powiatu na poziomie gminy

# %%
df_stats_powiat_by_gmina_2019 = calculate_partial_statistics(df_avg_taxed_income_2019,
                                                             level = 'Powiat',
                                                             by = 'Gmina'
                                                            )

df_stats_powiat_by_gmina_2020 = calculate_partial_statistics(df_avg_taxed_income_2020,
                                                             level = 'Powiat',
                                                             by = 'Gmina'
                                                            )

df_stats_powiat_by_gmina = df_stats_powiat_by_gmina_2019.merge(right = df_stats_powiat_by_gmina_2020,
                                                               how = 'outer',
                                                               on = ['Województwo', 'Powiat'],
                                                               suffixes = (' 2019', ' 2020')
                                                              )

df_stats_powiat_by_gmina
# Out:
# /home/adrian/npd/Projekt zaliczeniowy/npd_final_project/calculate_statistics/functions.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['proxy_var'] = temp[variable] * temp[weight]
#                                Średni dochód opodatkowany ludności 2019  \
# Województwo    Powiat
# dolnośląskie   bolesławiecki                               18964.265316
#                dzierżoniowski                              16973.261036
#                górowski                                    12962.266774
#                głogowski                                   26567.316675
#                jaworski                                    16425.013281
# ...                                                                 ...
# świętokrzyskie sandomierski                                14201.477697
#                skarżyski                                   17345.941883
#                starachowicki                               16849.368540
#                staszowski                                  14799.049657
#                włoszczowski                                13943.789043
#
#                                Wariancja dochodu (Gmina) 2019  \
# Województwo    Powiat
# dolnośląskie   bolesławiecki                     1.446413e+07
#                dzierżoniowski                    5.390741e+06
#                górowski                          4.485810e+06
#                głogowski                         6.998986e+07
#                jaworski                          6.778904e+06
# ...                                                       ...
# świętokrzyskie sandomierski                      1.672025e+07
#                skarżyski                         5.127483e+06
#                starachowicki                     1.044183e+07
#                staszowski                        1.640362e+07
#                włoszczowski                      1.160506e+07
#
#                                Średnia ważona dochodu (Gmina) 2019  \
# Województwo    Powiat
# dolnośląskie   bolesławiecki                          18356.871658
#                dzierżoniowski                         16429.633273
#                górowski                               12547.103775
#                głogowski                              25716.407355
#                jaworski                               15898.952064
# ...                                                            ...
# świętokrzyskie sandomierski                           13746.626193
#                skarżyski                              16790.379935
#                starachowicki                          16309.710422
#                staszowski                             14325.058537
#                włoszczowski                           13497.193468
#
#                                Średni dochód opodatkowany ludności 2020  \
# Województwo    Powiat
# dolnośląskie   bolesławiecki                               19432.895441
#                dzierżoniowski                              17497.491016
#                górowski                                    13482.364919
#                głogowski                                   26803.340491
#                jaworski                                    17227.593408
# ...                                                                 ...
# świętokrzyskie sandomierski                                14634.657493
#                skarżyski                                   17638.236883
#                starachowicki                               17620.853039
#                staszowski                                  14996.165881
#                włoszczowski                                14843.707359
#
#                                Wariancja dochodu (Gmina) 2020  \
# Województwo    Powiat
# dolnośląskie   bolesławiecki                     1.239560e+07
#                dzierżoniowski                    7.058378e+06
#                górowski                          6.201802e+06
#                głogowski                         6.466702e+07
#                jaworski                          7.864808e+06
# ...                                                       ...
# świętokrzyskie sandomierski                      1.729859e+07
#                skarżyski                         4.310161e+06
#                starachowicki                     1.003756e+07
#                staszowski                        1.660241e+07
#                włoszczowski                      1.342609e+07
#
#                                Średnia ważona dochodu (Gmina) 2020
# Województwo    Powiat
# dolnośląskie   bolesławiecki                          18849.993679
#                dzierżoniowski                         16972.643767
#                górowski                               13077.951940
#                głogowski                              25999.359978
#                jaworski                               16710.840554
# ...                                                            ...
# świętokrzyskie sandomierski                           14195.684849
#                skarżyski                              17109.170102
#                starachowicki                          17092.305454
#                staszowski                             14546.350925
#                włoszczowski                           14398.465440
#
# [314 rows x 6 columns]

# %% [markdown]
# ### Zapisanie wyników do pliku MS Excel

# %%
writer = pd.ExcelWriter(output_path + output_name_1, engine='xlsxwriter')

df_avg_income.to_excel(writer, sheet_name='Dochód i populacja', float_format="%.2f")
df_stats_woj_by_powiat.to_excel(writer, sheet_name='Statystyki województw (powiaty)', float_format="%.2f")
df_stats_woj_by_gmina.to_excel(writer, sheet_name='Statystyki województw (gminy)', float_format="%.2f")
df_stats_powiat_by_gmina.to_excel(writer, sheet_name='Statystyki powiatów (gminy)', float_format="%.2f")

writer.save()

# %% [markdown]
# # Funkcja zbiorcza wykonująca całą analizę i zapisująca wyniki

# %%
calculate_all_statistics(    input_path, name_gminy_2020, name_woj_2020,
                             name_miasta_npp_2020, name_powiaty_2020, name_metropolia_2020, 
                             name_gminy_2019, name_woj_2019, name_miasta_npp_2019,
                             name_powiaty_2019, name_metropolia_2019,
                             name_population,
                             output_path, output_name = output_name_2,
                             tax_perc_2020 = tax_perc_2019, tax_perc_2019 = tax_perc_2020,
                             working_people_share_2020 = working_people_share_2020,
                             working_people_share_2019 = working_people_share_2019
                        )
# Out:
# /home/adrian/npd/Projekt zaliczeniowy/npd_final_project/calculate_statistics/functions.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['proxy_var'] = temp[variable] * temp[weight]
